# %%
pwd
# Out:
# 'C:\\Users\\User\\Documents\\4 year BioEng\\AIHack\\diseases'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
admissions_data = pd.read_csv('diseases_all2.csv')

# %%
admissions_data.head(11)
# Out:
#     Year  All admissions  All admissions which can be caused by smoking  \
# 0   2008          440400                                         440400
# 1   2009          462900                                         462900
# 2   2010          461700                                         461700
# 3   2011          459900                                         459900
# 4   2012          459700                                         459700
# 5   2013          460900                                         460900
# 6   2014          454700                                         454700
# 7   2015          474600                                         474600
# 8   2016          474300                                         474300
# 9   2017          484700                                         484700
# 10  2018          489300                                         489300
#
#     Cancers which can be caused by smoking  \
# 0                                   161200
# ...

# %%
admissions_percentage_data = pd.read_csv('diseases_percentage.csv')

# %%
admissions_percentage_data.head(11)
# Out:
#     Year  All admissions  All admissions which can be caused by smoking  \
# 0   2008        4.965070                                      30.610384
# 1   2009        4.903467                                      31.019598
# 2   2010        4.739038                                      30.917481
# 3   2011        4.593138                                      29.976243
# 4   2012        4.522824                                      29.421484
# 5   2013        4.482806                                      28.801091
# 6   2014        4.288515                                      27.821533
# 7   2015        4.309890                                      27.700443
# 8   2016        4.217710                                      26.833947
# 9   2017        4.219549                                      26.559613
# 10  2018        4.226873                                      26.283242
#
#     Cancers which can be caused by smoking  \
# 0                                49.976948
# ...

# %%
frames = [admissions_data,admissions_percentage_data]
df_keys = pd.concat(frames, keys=['Attributable number', 'Attributable percentage'])

# %%
df_keys
# Out:
#                             Year  All admissions  \
# Attributable number     0   2008   440400.000000
#                         1   2009   462900.000000
#                         2   2010   461700.000000
#                         3   2011   459900.000000
#                         4   2012   459700.000000
#                         5   2013   460900.000000
#                         6   2014   454700.000000
#                         7   2015   474600.000000
#                         8   2016   474300.000000
#                         9   2017   484700.000000
#                         10  2018   489300.000000
# Attributable percentage 0   2008        4.965070
#                         1   2009        4.903467
#                         2   2010        4.739038
#                         3   2011        4.593138
#                         4   2012        4.522824
#                         5   2013        4.482806
#                         6   2014        4.288515
# ...

# %%
# Read the cancer related data

xls_cancers_prevalence17 = pd.read_excel('cancerregistrations2017final.xlsx', sheet_name = "Table 1")
xls_cancers_prevalence17.to_csv('cancerregistrations2017final.csv', encoding='utf-8')

for i in range(7):
    xls_cancers_prevalence1 = pd.read_excel('cancerregistrations201' + str(i) + 'final.xls', sheet_name = "Table 1")
    xls_cancers_prevalence1.to_csv('cancerregistrations201' + str(i) + 'final.csv', encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-fe8f61e2d74b> in <module>
#       5
#       6 for i in range(7):
# ----> 7     xls_cancers_prevalence1[i] = pd.read_excel('cancerregistrations201' + str(i) + 'final.xls', sheet_name = "Table 1")
#       8     xls_cancers_prevalence1[i].to_csv('cancerregistrations201' + str(i) + 'final.csv', encoding='utf-8')
#
# NameError: name 'xls_cancers_prevalence1' is not defined

# %%
for i in range(9):
    xls_cancers_prevalence0 = pd.read_excel('cancerregistrations200' + str(i) + 'final.xls', sheet_name = "Table 1")
    xls_cancers_prevalence0.to_csv('cancerregistrations200' + str(i) + 'final.csv', encoding='utf-8')

# %%
# Out:
#    Unnamed: 0                                           Contents  \
# 0         NaN                                                NaN
# 1         NaN  Table 1: Registrations of newly diagnosed case...
# 2         NaN                                                NaN
# 3         NaN                                                NaN
# 4         NaN                                        ICD-10 code
#
#          Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0               NaN        NaN        NaN        NaN        NaN        NaN
# 1               NaN        NaN        NaN        NaN        NaN        NaN
# 2               NaN        NaN        NaN        NaN        NaN        NaN
# 3               NaN        NaN        NaN  Age group        NaN        NaN
# 4  Site description        NaN   All ages    Under 1     1 to 4     5 to 9
#
#   Unnamed: 8 Unnamed: 9  ... Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18  \
# ...
